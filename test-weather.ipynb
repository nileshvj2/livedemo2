# %%
import requests
import os
# No API key needed at all
url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 41.85,   # Chicago
    "longitude": -87.65,
    "current": "temperature_2m,relative_humidity_2m,weather_code"
}
response = requests.get(url, params=params)
print(response.json())
# Out:
# {'latitude': 41.85271, 'longitude': -87.65361, 'generationtime_ms': 0.0972747802734375, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 179.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C', 'relative_humidity_2m': '%', 'weather_code': 'wmo code'}, 'current': {'time': '2026-06-03T17:30', 'interval': 900, 'temperature_2m': 25.4, 'relative_humidity_2m': 28, 'weather_code': 3}}

# %%
# 
# create a api call using openweather map, use key in env file
import requests
import os

url = "http://api.openweathermap.org/data/2.5/weather"
params = {
    "q": "London",
    "appid": os.getenv("WEATHER_API_KEY")
}
response = requests.get(url, params=params) 
print(response.json())
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 290.37, 'feels_like': 290.08, 'temp_min': 289.05, 'temp_max': 291.07, 'pressure': 998, 'humidity': 74, 'sea_level': 998, 'grnd_level': 994}, 'visibility': 10000, 'wind': {'speed': 8.94, 'deg': 177, 'gust': 11.18}, 'clouds': {'all': 62}, 'dt': 1780509730, 'sys': {'type': 2, 'id': 2075535, 'country': 'GB', 'sunrise': 1780458467, 'sunset': 1780517388}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}
